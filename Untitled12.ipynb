# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext lab_black
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
from summergreen import fetchers
import redis
import pandas as pd
from dask import dataframe as dd

# %%
from summergreen import schedulers

# %%
sf = fetchers.SinaStockFetcher(
    redis_host="localhost",
    redis_port=6379,
    redis_db=0,
    parquet_dir="/mnt/stock_data/tmp_cudf/",
)

# %%
sf.day_initialization()

# %%
sf.snap2redis()
# Out:
# start to fetch.

# %%
sf.redis2parquet()

# %%
pd.read_parquet("""/mnt/stock_data/tmp_cudf/2020-05-27.parquet""")
# Out:
#                             current   high     low      volume         money  \
# code   time
# 162006 2020-05-26 15:00:03    1.640   1.64   1.613     90032.0  1.456009e+05
# 000821 2020-05-26 15:00:03    5.960   6.00   5.730   4294300.0  2.541088e+07
# 000620 2020-05-26 15:00:03    3.530   3.70   3.400  40946972.0  1.439196e+08
# 601988 2020-05-26 15:00:00    3.430   3.45   3.430  38100641.0  1.309472e+08
# 600870 2020-05-26 15:00:00    2.850   2.86   2.740   1817541.0  5.145751e+06
# ...                             ...    ...     ...         ...           ...
# 002419 2020-05-26 15:00:03    8.940   8.96   8.800   4748129.0  4.225765e+07
# 150009 2020-05-26 15:00:03    1.026   1.03   1.016    103983.0  1.062929e+05
# 165525 2020-05-26 15:00:03    0.660   0.66   0.656  32757702.0  2.156331e+07
# 603198 2020-05-26 15:00:00   17.320  17.36  16.910   6004255.0  1.031790e+08
# 002850 2020-05-26 15:00:03   55.260  55.68  51.260   4058250.0  2.200037e+08
#
# ...
